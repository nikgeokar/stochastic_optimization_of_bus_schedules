# %% [markdown]
# ## Import Packages - Libraries

# %%
from docplex.mp.model import Model
import time
import numpy as np
from os.path import join
import pickle
from datetime import datetime, timedelta
import pandas as pd

# %% [markdown]
# ## Global Variable

# %%
input_path = join("io", "input")
output_path = join("io", "output")

# %% [markdown]
# ## Load Input Data

# %%
def load_dict_from_file(filepath):
    """
    Load a dictionary from a pickle file.
    """
    with open(filepath, 'rb') as file:
        return pickle.load(file)

# %%
def load_data(output_path):
    schedules = load_dict_from_file(join(output_path, "fct_schedules_mean_sub"))
    gap_dict = load_dict_from_file(join(output_path, "fct_gap_passengers_sub"))
    stop_factor = load_dict_from_file(join(output_path, "interm_stop_factor"))
    return schedules, gap_dict, stop_factor

# %% [markdown]
# ## Preprocess Parameters

# %%
def get_lines_and_stops(schedules):
    """
    Extracts and returns sorted lists of all distinct lines and all distinct stops.
    """
    bus_lines = sorted(schedules.keys())
    
    # Use a set to collect unique stops
    all_stops = set()
    for line in schedules:
        all_stops.update(schedules[line].keys())
    
    stops = sorted(all_stops)
    
    return bus_lines, stops

# %%
def get_schedules_actual_start_times(schedules):

    # Define reference start time
    start_time = datetime.strptime("06:59", "%H:%M")
    
    start_times_dict = {}
    
    for bus, stops in schedules.items():
        first_stop = next(iter(stops))  # Get the first stop key
        eta_minutes = stops[first_stop]
    
        # Convert to HH:MM time format
        eta_times = [(start_time + timedelta(minutes=eta)).strftime("%H:%M") for eta in eta_minutes]
    
        # Store in dict
        start_times_dict[bus] = eta_times
    return start_times_dict

# %%
def get_opt_parameters(output_path):
    schedules, gap_dict, stop_factor = load_data(output_path)

    bus_lines, stops = get_lines_and_stops(schedules)
    schedules_per_line = {line: max(len(times) for times in stops.values()) for line, stops in schedules.items()}
    max_gap_threshold = {stop_id: 200 for stop_id in stop_factor}
    
    start_times_dict = get_schedules_actual_start_times(schedules)
    
    max_lines = {'b00_w': 2, 'b02_w': 4, 'b05_w': 4, 'b06_w': 4, 'b07_w': 4, 'b10_w': 4, 'b12_w': 4,
                 'b14_w': 4, 'b30_w': 4, 'b31_w': 4, 'b33_w': 4, 'b37_w': 4, 'b39_w': 4}
    
    min_service_requirements = {
        '15085': {"min_service": 2, "time_frame": (0, 100)}
    }

    return schedules, gap_dict, stop_factor, bus_lines, stops, schedules_per_line, max_gap_threshold, start_times_dict, max_lines, min_service_requirements

# %% [markdown]
# ## Set Up Optmimization Model

# %%
def create_opt_model():
    mdl = Model(name='bus_scheduling')
    return mdl

# %%
def define_decision_variable(mdl, schedules, schedules_per_line):
    x = mdl.binary_var_dict(
        keys=[(line, j) for line in schedules for j in range(1, schedules_per_line[line] + 1)],
        name='x')

    print ("Decision variable has been created")
    return x

# %% [markdown]
# ## Setup Operational Constraints

# %%
def max_schedules_constraint(mdl, x, bus_lines, schedules_per_line, max_lines):
# Each bus line must run at least 1 schedule
    for line in bus_lines:
        if line != 'b00_w':
            constraint = mdl.add_constraint(mdl.sum(x[line, j] for j in range(1, schedules_per_line[line] + 1)) == max_lines[line], ctname=f'run_{line}')
            print(f"Constraint for {line}: {constraint}")
    return True

# %%
def start_end_limit_constraint(mdl, x, schedules_per_line):
    for j in range(1, schedules_per_line['b00_w'] + 1):  # Loop through all schedule indices
        mdl.add_constraint(x['b00_w', j] == 1, ctname=f'force_all_bus00_schedule_{j}')

    print('Start - End Limit Constraint has bee added successfully')
    return True

# %%
def minimum_stop_service_constraint(mdl, x, min_service_requirements, bus_lines, schedules, schedules_per_line):
    # Add constraints for minimum service at specific stops
    for stop, requirement in min_service_requirements.items():
        min_service = requirement["min_service"]
        time_frame = requirement["time_frame"]
        start_time, end_time = time_frame
    
        # Collect schedules that fall within the specified time frame
        valid_schedules = [
            x[bus, j]
            for bus in bus_lines  # Loop through all bus lines
            if stop in schedules[bus]  # Check if the bus serves this stop
            for j in range(1, schedules_per_line[bus] + 1)  # Loop through all schedules for the bus
            if schedules[bus][stop][j - 1] >= start_time and schedules[bus][stop][j - 1] <= end_time
        ]
        
        # Add the constraint for the minimum number of schedules
        mdl.add_constraint(
            sum(valid_schedules) >= min_service,
            f'min_service_{stop}'
        )

    print('Minimum Stop Service Constraint has been added')
    return True

# %% [markdown]
# ## Setup Objective Function

# %%
def max_gap_constraint(mdl, x, stops, bus_lines, schedules, schedules_per_line, gap_dict, max_gap_threshold):
    # Define maximum gap variables for each stop
    max_gaps = {stop: mdl.continuous_var(name=f'max_gap_{stop}') for stop in stops}
    
    
    # Add constraints to define the maximum gaps based on the variable decisions
    gap_results = {}
    for stop in stops:
        print('Calculating Max Gap for stop:', stop)
        all_possible_times = []
        all_possible_times2 = []
        for line in bus_lines:           # Loop through each bus line
            if stop in schedules[line]:  # Check if the current stop is served by the current bus line
                for j in range(1, schedules_per_line[line] + 1):    # Loop through each schedule option (assuming there are 2 options per line)
                    time_expr = x[line, j] * schedules[line][stop][j-1]
                    all_possible_times.append(time_expr)     # Append the time to the list of possible times
                    all_possible_times2.append(schedules[line][stop][j-1])
        max_gap_var, is_lower_out_vars, is_greater_out_vars, is_totaly_out_vars, include_pairs_vars = calculate_max_gap(all_possible_times, all_possible_times2, max_gaps[stop], stop, mdl, gap_dict)
        gap_results[stop] = (max_gap_var, is_lower_out_vars, is_greater_out_vars, is_totaly_out_vars, include_pairs_vars)
    
        threshold = max_gap_threshold[stop]
        threshold_constraint = mdl.add_constraint(max_gap_var <= threshold, f'max_gap_threshold_{stop}')
        print(f"Threshold constraint for {stop}: {threshold_constraint}")
    
        gap_constraint = mdl.add_constraint(max_gaps[stop] == max_gap_var)
        print(f"Gap constraint for {stop}: {gap_constraint}")

    return max_gaps, gap_results

# %%
def calculate_max_gap(all_possible_times, all_possible_times2, max_gap_var, stop, mdl, gap_dict):
    print(f"Calculating gaps for stop {stop} with possible times: {all_possible_times}")
    # Example hardcoded limit
    gaps = []
    is_greater_out_vars = []  # List to store for debugging within the function scope
    is_lower_out_vars = []
    is_totaly_out_vars = []
    include_pairs_vars = []

    n_times = len(all_possible_times)    
    # Precompute min and max relationships
    min_matrix = [[None for _ in range(n_times)] for _ in range(n_times)]
    max_matrix = [[None for _ in range(n_times)] for _ in range(n_times)]

    for i in range(n_times - 1):
        for j in range(i + 1, n_times):
            min_matrix[i][j] = min(all_possible_times2[i], all_possible_times2[j])
            max_matrix[i][j] = max(all_possible_times2[i], all_possible_times2[j])


    # Here we loop over all possible time to calualte the max bettwen every pair
    for i in range(len(all_possible_times) - 1):
        for j in range(i + 1, len(all_possible_times)):
            gap_abs = mdl.continuous_var(name=f"gap_abs_{stop}_{i}_{j}", lb=0)
            gap = mdl.continuous_var(name=f"gap_{stop}_{i}_{j}", lb=0)
            gap_key = f"gap_{stop}_{i}_{j}_{all_possible_times2[i]}_{all_possible_times2[j]}"
            include_pairs = mdl.binary_var(name=f"include_pairs_{stop}_{i}_{j}")
            
            is_totally_out_ls = []
            #Here we check if that pair has no othe time between by looping again on the othe times
            for k in range(len(all_possible_times)):
                is_lower_out = mdl.binary_var(name=f"is_lower_out_{stop}_{i}_{j}_{k}")
                is_greater_out = mdl.binary_var(name=f"is_greater_out_{stop}_{i}_{j}_{k}")
                is_totaly_out = mdl.binary_var(name=f"combined_{stop}_{i}_{j}_{k}")
                if k != i and k != j:

                    min_ij = min_matrix[i][j]
                    max_ij = max_matrix[i][j]
                
                    # Indicator for is_lower_out
                    mdl.add_indicator(is_lower_out, all_possible_times[k] - min_ij >= 1, 0)
                    mdl.add_indicator(is_lower_out, all_possible_times[k] - min_ij <= 0, 1)
                    
                    # New indicator for is_greater_out
                    mdl.add_indicator(is_greater_out, max_ij - all_possible_times[k] >= 1, 0)
                    mdl.add_indicator(is_greater_out, max_ij - all_possible_times[k] <= 0, 1)

                    # If the other time is less than the minimum between time of the pair or max than the maximum 
                    # Then this pair has the potential to be inculded on the max time gap calculation 
                    mdl.add_constraint(is_totaly_out >= is_lower_out)
                    mdl.add_constraint(is_totaly_out >= is_greater_out)
                    mdl.add_constraint(is_totaly_out <= is_lower_out + is_greater_out)

                    is_lower_out_vars.append((is_lower_out, i, j, k))
                    is_greater_out_vars.append((is_greater_out, i, j, k))
                    is_totaly_out_vars.append((is_totaly_out, i, j, k))
                    is_totally_out_ls.append(is_totaly_out)        
            
            if gap_key in gap_dict:
                gap_value = gap_dict[gap_key]
            else:
                raise ValueError(f"Gap key {gap_key} not found in precomputed gaps")

            #Define binary variables for selection conditions
            is_selected_i = mdl.binary_var(name=f"is_selected_{stop}_{i}_{j}_{i}")
            is_selected_j = mdl.binary_var(name=f"is_selected_{stop}_{i}_{j}_{j}")
            
            # Add indicators to define when all_possible_times[i] and all_possible_times[j] are greater than 1
            # Constraints to determine if all_possible_times[i] and all_possible_times[j] are selected
            mdl.add_constraint(is_selected_i == (all_possible_times[i] >= 1))
            mdl.add_constraint(is_selected_j == (all_possible_times[j] >= 1))
            
            # Define an auxiliary binary variable to capture the AND condition
            z_and = mdl.binary_var(name=f"z_and_{stop}_{i}_{j}")
            
            # Add constraints for the AND condition
            mdl.add_constraint(z_and <= is_selected_i)
            mdl.add_constraint(z_and <= is_selected_j)
            mdl.add_constraint(z_and >= is_selected_i + is_selected_j - 1)

            mdl.add_constraint(include_pairs == mdl.min(is_totally_out_ls))
            
            mdl.add_indicator(include_pairs, gap == gap_value * z_and, 1)
            mdl.add_indicator(include_pairs, gap == 0, 0)
            
            gaps.append(gap)
            include_pairs_vars.append((include_pairs, i, j))

    if gaps:
        mdl.add_constraint(max_gap_var == mdl.max(gaps), f'max_gap_constraint_{stop}')

    return max_gap_var, is_lower_out_vars, is_greater_out_vars, is_totaly_out_vars, include_pairs_vars  # Return the maximum gap variable directly

# %%
def add_objective_function(mdl,stop_factor, max_gaps, stops):
    # Objective: Minimize the average maximum gap at each stop
    weighted_gaps = mdl.sum(stop_factor[stop] * max_gaps[stop] for stop in stops)
    objective = weighted_gaps / len(stops)
    mdl.minimize(objective)

    print('Objective Function has been created')
    return True

# %% [markdown]
# ## Solve Model

# %%
def solve(mdl, x, gap_results, stops, bus_lines, start_times_dict, logs=False):
    # Solve the model
    solution = mdl.solve(log_output=True)

    if solution:
        final_schedule_df = print_solution(x, stops, gap_results, bus_lines, schedules_per_line, start_times_dict)
        print(f"Average maximum gap (Objective value): {mdl.objective_value}")
    else:
        print("No solution found")

    if logs:
        print_logs(stops, gap_results)

    return final_schedule_df

# %% [markdown]
# ## Print Results & Logs

# %%
def print_solution(x, stops, gap_results, bus_lines, schedules_per_line, start_times_dict):
    bus_ls = []
    start_times_ls = []
    for stop in stops:
        max_gap_var, is_lower_out_vars, is_greater_out_vars, is_totaly_out_vars, include_pairs_vars = gap_results[stop]
        print(f"Maximum gap at {stop}: {max_gap_var.solution_value}")
    for line in bus_lines:
        if line == 'b00_w':
            continue
        print(f"Selected schedules for {line}:")     
        for j in range(1, schedules_per_line[line] + 1):
            print(f"  Schedule Starts At {start_times_dict[line][j-1]}: {x[line, j].solution_value}")
            if x[line, j].solution_value:
                bus_ls.append(line)
                start_times_ls.append(start_times_dict[line][j-1])
    final_schedule_df = pd.DataFrame(list(zip(bus_ls, start_times_ls)), columns=['bus_name', 'start_time'])
    return final_schedule_df

# %%
def print_logs(stops, gap_results):
    for stop in stops:
        max_gap_var, is_lower_out_vars, is_greater_out_vars, is_totaly_out_vars, include_pairs_vars = gap_results[stop]
        print(f"is_lower_out values for {stop}:")
        for is_lower_out, i, j, k in is_lower_out_vars:
            print(f"is_lower_out for pair {i}-{j}-{k}: {is_lower_out.solution_value}")

        print(f"is_greater_out values for {stop}:")
        for is_greater_out, i, j, k in is_greater_out_vars:
            print(f"is_greater_out for pair {i}-{j}-{k}: {is_greater_out.solution_value}")

        print(f"is_totaly_out values for {stop}:")
        for is_totaly_out, i, j, k in is_totaly_out_vars:
            print(f"is_totaly_out for pair {i}-{j}-{k}: {is_totaly_out.solution_value}")
            
        print(f"include_pairs_vars values for {stop}:")
        for include_pairs, i, j in include_pairs_vars:
            print(f"include_pairs for pair {i}-{j}: {include_pairs.solution_value}")
        
    return True

# %% [markdown]
# ## Optmization Pipeline

# %%
def optimize_bus_schedule(stops, schedules, schedules_per_line, bus_lines, max_lines, min_service_requirements, gap_dict, max_gap_threshold, stop_factor, start_times_dict):

    start_time = time.perf_counter()
    
    mdl = create_opt_model()
    x = define_decision_variable(mdl, schedules, schedules_per_line)
    status = max_schedules_constraint(mdl, x, bus_lines, schedules_per_line, max_lines)
    status = start_end_limit_constraint(mdl, x, schedules_per_line)
    status = minimum_stop_service_constraint(mdl, x, min_service_requirements, bus_lines, schedules, schedules_per_line)
    max_gaps, gap_results = max_gap_constraint(mdl, x, stops, bus_lines, schedules, schedules_per_line, gap_dict, max_gap_threshold)
    status = add_objective_function(mdl, stop_factor, max_gaps, stops)
    final_schedule_df = solve(mdl, x, gap_results, stops, bus_lines, start_times_dict, logs=False)

    end_time = time.perf_counter()
    execution_time = end_time - start_time
    print(execution_time)

    return final_schedule_df

# %% [markdown]
# ## Execution

# %%
schedules, gap_dict, stop_factor, bus_lines, stops, schedules_per_line, max_gap_threshold, start_times_dict, max_lines, min_service_requirements = get_opt_parameters(output_path)

final_schedule_df = optimize_bus_schedule(stops, schedules, schedules_per_line, bus_lines, max_lines, min_service_requirements, gap_dict, max_gap_threshold, stop_factor, start_times_dict)
# Out:
# Decision variable has been created
# Constraint for b02_w: run_b02_w: x_b02_w_1+x_b02_w_2+x_b02_w_3+x_b02_w_4+x_b02_w_5+x_b02_w_6+x_b02_w_7+x_b02_w_8 == 4
# Constraint for b05_w: run_b05_w: x_b05_w_1+x_b05_w_2+x_b05_w_3+x_b05_w_4+x_b05_w_5+x_b05_w_6+x_b05_w_7+x_b05_w_8 == 4
# Constraint for b06_w: run_b06_w: x_b06_w_1+x_b06_w_2+x_b06_w_3+x_b06_w_4+x_b06_w_5+x_b06_w_6+x_b06_w_7+x_b06_w_8 == 4
# Constraint for b07_w: run_b07_w: x_b07_w_1+x_b07_w_2+x_b07_w_3+x_b07_w_4+x_b07_w_5+x_b07_w_6+x_b07_w_7+x_b07_w_8 == 4
# Constraint for b10_w: run_b10_w: x_b10_w_1+x_b10_w_2+x_b10_w_3+x_b10_w_4+x_b10_w_5+x_b10_w_6+x_b10_w_7+x_b10_w_8 == 4
# Constraint for b12_w: run_b12_w: x_b12_w_1+x_b12_w_2+x_b12_w_3+x_b12_w_4+x_b12_w_5+x_b12_w_6+x_b12_w_7+x_b12_w_8 == 4
# Constraint for b14_w: run_b14_w: x_b14_w_1+x_b14_w_2+x_b14_w_3+x_b14_w_4+x_b14_w_5+x_b14_w_6+x_b14_w_7+x_b14_w_8 == 4
# Constraint for b30_w: run_b30_w: x_b30_w_1+x_b30_w_2+x_b30_w_3+x_b30_w_4+x_b30_w_5+x_b30_w_6+x_b30_w_7+x_b30_w_8 == 4
# Constraint for b31_w: run_b31_w: x_b31_w_1+x_b31_w_2+x_b31_w_3+x_b31_w_4+x_b31_w_5+x_b31_w_6+x_b31_w_7+x_b31_w_8 == 4
# Constraint for b33_w: run_b33_w: x_b33_w_1+x_b33_w_2+x_b33_w_3+x_b33_w_4+x_b33_w_5+x_b33_w_6+x_b33_w_7+x_b33_w_8 == 4
# Constraint for b37_w: run_b37_w: x_b37_w_1+x_b37_w_2+x_b37_w_3+x_b37_w_4+x_b37_w_5+x_b37_w_6+x_b37_w_7+x_b37_w_8 == 4
# Constraint for b39_w: run_b39_w: x_b39_w_1+x_b39_w_2+x_b39_w_3+x_b39_w_4+x_b39_w_5+x_b39_w_6+x_b39_w_7+x_b39_w_8 == 4
# Start - End Limit Constraint has bee added successfully
# Minimum Stop Service Constraint has been added
# Calculating Max Gap for stop: 1004
# Calculating gaps for stop 1004 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(12x_b14_w_1), docplex.mp.MonomialExpr(27x_b14_w_2), docplex.mp.MonomialExpr(43x_b14_w_3), docplex.mp.MonomialExpr(57x_b14_w_4), docplex.mp.MonomialExpr(72x_b14_w_5), docplex.mp.MonomialExpr(87x_b14_w_6), docplex.mp.MonomialExpr(103x_b14_w_7), docplex.mp.MonomialExpr(118x_b14_w_8), docplex.mp.MonomialExpr(48x_b30_w_1), docplex.mp.MonomialExpr(64x_b30_w_2), docplex.mp.MonomialExpr(78x_b30_w_3), docplex.mp.MonomialExpr(94x_b30_w_4), docplex.mp.MonomialExpr(109x_b30_w_5), docplex.mp.MonomialExpr(124x_b30_w_6), docplex.mp.MonomialExpr(139x_b30_w_7), docplex.mp.MonomialExpr(154x_b30_w_8)]
# Threshold constraint for 1004: max_gap_threshold_1004: max_gap_1004 <= 600
# Gap constraint for 1004: max_gap_1004 == max_gap_1004
# Calculating Max Gap for stop: 1005
# Calculating gaps for stop 1005 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(10x_b14_w_1), docplex.mp.MonomialExpr(24x_b14_w_2), docplex.mp.MonomialExpr(40x_b14_w_3), docplex.mp.MonomialExpr(55x_b14_w_4), docplex.mp.MonomialExpr(70x_b14_w_5), docplex.mp.MonomialExpr(85x_b14_w_6), docplex.mp.MonomialExpr(100x_b14_w_7), docplex.mp.MonomialExpr(115x_b14_w_8)]
# Threshold constraint for 1005: max_gap_threshold_1005: max_gap_1005 <= 600
# Gap constraint for 1005: max_gap_1005 == max_gap_1005
# Calculating Max Gap for stop: 1024
# Calculating gaps for stop 1024 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(104x_b02_w_1), docplex.mp.MonomialExpr(120x_b02_w_2), docplex.mp.MonomialExpr(133x_b02_w_3), docplex.mp.MonomialExpr(148x_b02_w_4), docplex.mp.MonomialExpr(162x_b02_w_5), docplex.mp.MonomialExpr(177x_b02_w_6), docplex.mp.MonomialExpr(192x_b02_w_7), docplex.mp.MonomialExpr(206x_b02_w_8), docplex.mp.MonomialExpr(67x_b14_w_1), docplex.mp.MonomialExpr(81x_b14_w_2), docplex.mp.MonomialExpr(96x_b14_w_3), docplex.mp.MonomialExpr(111x_b14_w_4), docplex.mp.MonomialExpr(126x_b14_w_5), docplex.mp.MonomialExpr(141x_b14_w_6), docplex.mp.MonomialExpr(156x_b14_w_7), docplex.mp.MonomialExpr(170x_b14_w_8), docplex.mp.MonomialExpr(48x_b31_w_1), docplex.mp.MonomialExpr(63x_b31_w_2), docplex.mp.MonomialExpr(78x_b31_w_3), docplex.mp.MonomialExpr(94x_b31_w_4), docplex.mp.MonomialExpr(109x_b31_w_5), docplex.mp.MonomialExpr(124x_b31_w_6), docplex.mp.MonomialExpr(138x_b31_w_7), docplex.mp.MonomialExpr(152x_b31_w_8), docplex.mp.MonomialExpr(52x_b37_w_1), docplex.mp.MonomialExpr(67x_b37_w_2), docplex.mp.MonomialExpr(82x_b37_w_3), docplex.mp.MonomialExpr(97x_b37_w_4), docplex.mp.MonomialExpr(112x_b37_w_5), docplex.mp.MonomialExpr(127x_b37_w_6), docplex.mp.MonomialExpr(142x_b37_w_7), docplex.mp.MonomialExpr(157x_b37_w_8), docplex.mp.MonomialExpr(78x_b39_w_1), docplex.mp.MonomialExpr(94x_b39_w_2), docplex.mp.MonomialExpr(107x_b39_w_3), docplex.mp.MonomialExpr(123x_b39_w_4), docplex.mp.MonomialExpr(139x_b39_w_5), docplex.mp.MonomialExpr(151x_b39_w_6), docplex.mp.MonomialExpr(166x_b39_w_7), docplex.mp.MonomialExpr(181x_b39_w_8)]
# Threshold constraint for 1024: max_gap_threshold_1024: max_gap_1024 <= 600
# Gap constraint for 1024: max_gap_1024 == max_gap_1024
# Calculating Max Gap for stop: 1027
# Calculating gaps for stop 1027 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(84x_b05_w_1), docplex.mp.MonomialExpr(99x_b05_w_2), docplex.mp.MonomialExpr(115x_b05_w_3), docplex.mp.MonomialExpr(129x_b05_w_4), docplex.mp.MonomialExpr(143x_b05_w_5), docplex.mp.MonomialExpr(157x_b05_w_6), docplex.mp.MonomialExpr(172x_b05_w_7), docplex.mp.MonomialExpr(186x_b05_w_8), docplex.mp.MonomialExpr(82x_b06_w_1), docplex.mp.MonomialExpr(96x_b06_w_2), docplex.mp.MonomialExpr(112x_b06_w_3), docplex.mp.MonomialExpr(128x_b06_w_4), docplex.mp.MonomialExpr(141x_b06_w_5), docplex.mp.MonomialExpr(155x_b06_w_6), docplex.mp.MonomialExpr(171x_b06_w_7), docplex.mp.MonomialExpr(185x_b06_w_8), docplex.mp.MonomialExpr(47x_b10_w_1), docplex.mp.MonomialExpr(62x_b10_w_2), docplex.mp.MonomialExpr(77x_b10_w_3), docplex.mp.MonomialExpr(91x_b10_w_4), docplex.mp.MonomialExpr(107x_b10_w_5), docplex.mp.MonomialExpr(123x_b10_w_6), docplex.mp.MonomialExpr(137x_b10_w_7), docplex.mp.MonomialExpr(151x_b10_w_8), docplex.mp.MonomialExpr(48x_b12_w_1), docplex.mp.MonomialExpr(63x_b12_w_2), docplex.mp.MonomialExpr(77x_b12_w_3), docplex.mp.MonomialExpr(92x_b12_w_4), docplex.mp.MonomialExpr(107x_b12_w_5), docplex.mp.MonomialExpr(122x_b12_w_6), docplex.mp.MonomialExpr(137x_b12_w_7), docplex.mp.MonomialExpr(151x_b12_w_8), docplex.mp.MonomialExpr(88x_b33_w_1), docplex.mp.MonomialExpr(102x_b33_w_2), docplex.mp.MonomialExpr(119x_b33_w_3), docplex.mp.MonomialExpr(132x_b33_w_4), docplex.mp.MonomialExpr(146x_b33_w_5), docplex.mp.MonomialExpr(161x_b33_w_6), docplex.mp.MonomialExpr(177x_b33_w_7), docplex.mp.MonomialExpr(190x_b33_w_8)]
# Threshold constraint for 1027: max_gap_threshold_1027: max_gap_1027 <= 600
# Gap constraint for 1027: max_gap_1027 == max_gap_1027
# Calculating Max Gap for stop: 1042
# Calculating gaps for stop 1042 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(102x_b02_w_1), docplex.mp.MonomialExpr(117x_b02_w_2), docplex.mp.MonomialExpr(131x_b02_w_3), docplex.mp.MonomialExpr(145x_b02_w_4), docplex.mp.MonomialExpr(159x_b02_w_5), docplex.mp.MonomialExpr(175x_b02_w_6), docplex.mp.MonomialExpr(189x_b02_w_7), docplex.mp.MonomialExpr(204x_b02_w_8), docplex.mp.MonomialExpr(64x_b14_w_1), docplex.mp.MonomialExpr(79x_b14_w_2), docplex.mp.MonomialExpr(93x_b14_w_3), docplex.mp.MonomialExpr(109x_b14_w_4), docplex.mp.MonomialExpr(124x_b14_w_5), docplex.mp.MonomialExpr(138x_b14_w_6), docplex.mp.MonomialExpr(153x_b14_w_7), docplex.mp.MonomialExpr(167x_b14_w_8), docplex.mp.MonomialExpr(46x_b31_w_1), docplex.mp.MonomialExpr(61x_b31_w_2), docplex.mp.MonomialExpr(75x_b31_w_3), docplex.mp.MonomialExpr(91x_b31_w_4), docplex.mp.MonomialExpr(106x_b31_w_5), docplex.mp.MonomialExpr(121x_b31_w_6), docplex.mp.MonomialExpr(135x_b31_w_7), docplex.mp.MonomialExpr(150x_b31_w_8), docplex.mp.MonomialExpr(50x_b37_w_1), docplex.mp.MonomialExpr(64x_b37_w_2), docplex.mp.MonomialExpr(80x_b37_w_3), docplex.mp.MonomialExpr(94x_b37_w_4), docplex.mp.MonomialExpr(109x_b37_w_5), docplex.mp.MonomialExpr(124x_b37_w_6), docplex.mp.MonomialExpr(139x_b37_w_7), docplex.mp.MonomialExpr(154x_b37_w_8), docplex.mp.MonomialExpr(76x_b39_w_1), docplex.mp.MonomialExpr(91x_b39_w_2), docplex.mp.MonomialExpr(105x_b39_w_3), docplex.mp.MonomialExpr(120x_b39_w_4), docplex.mp.MonomialExpr(136x_b39_w_5), docplex.mp.MonomialExpr(149x_b39_w_6), docplex.mp.MonomialExpr(163x_b39_w_7), docplex.mp.MonomialExpr(178x_b39_w_8)]
# Threshold constraint for 1042: max_gap_threshold_1042: max_gap_1042 <= 600
# Gap constraint for 1042: max_gap_1042 == max_gap_1042
# Calculating Max Gap for stop: 1045
# Calculating gaps for stop 1045 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(99x_b02_w_1), docplex.mp.MonomialExpr(115x_b02_w_2), docplex.mp.MonomialExpr(128x_b02_w_3), docplex.mp.MonomialExpr(143x_b02_w_4), docplex.mp.MonomialExpr(157x_b02_w_5), docplex.mp.MonomialExpr(172x_b02_w_6), docplex.mp.MonomialExpr(187x_b02_w_7), docplex.mp.MonomialExpr(201x_b02_w_8), docplex.mp.MonomialExpr(62x_b14_w_1), docplex.mp.MonomialExpr(76x_b14_w_2), docplex.mp.MonomialExpr(91x_b14_w_3), docplex.mp.MonomialExpr(106x_b14_w_4), docplex.mp.MonomialExpr(121x_b14_w_5), docplex.mp.MonomialExpr(136x_b14_w_6), docplex.mp.MonomialExpr(151x_b14_w_7), docplex.mp.MonomialExpr(165x_b14_w_8), docplex.mp.MonomialExpr(43x_b31_w_1), docplex.mp.MonomialExpr(58x_b31_w_2), docplex.mp.MonomialExpr(73x_b31_w_3), docplex.mp.MonomialExpr(88x_b31_w_4), docplex.mp.MonomialExpr(104x_b31_w_5), docplex.mp.MonomialExpr(119x_b31_w_6), docplex.mp.MonomialExpr(133x_b31_w_7), docplex.mp.MonomialExpr(147x_b31_w_8), docplex.mp.MonomialExpr(47x_b37_w_1), docplex.mp.MonomialExpr(62x_b37_w_2), docplex.mp.MonomialExpr(77x_b37_w_3), docplex.mp.MonomialExpr(92x_b37_w_4), docplex.mp.MonomialExpr(107x_b37_w_5), docplex.mp.MonomialExpr(122x_b37_w_6), docplex.mp.MonomialExpr(137x_b37_w_7), docplex.mp.MonomialExpr(152x_b37_w_8), docplex.mp.MonomialExpr(73x_b39_w_1), docplex.mp.MonomialExpr(89x_b39_w_2), docplex.mp.MonomialExpr(102x_b39_w_3), docplex.mp.MonomialExpr(118x_b39_w_4), docplex.mp.MonomialExpr(134x_b39_w_5), docplex.mp.MonomialExpr(146x_b39_w_6), docplex.mp.MonomialExpr(161x_b39_w_7), docplex.mp.MonomialExpr(176x_b39_w_8)]
# Threshold constraint for 1045: max_gap_threshold_1045: max_gap_1045 <= 600
# Gap constraint for 1045: max_gap_1045 == max_gap_1045
# Calculating Max Gap for stop: 1047
# Calculating gaps for stop 1047 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(97x_b02_w_1), docplex.mp.MonomialExpr(112x_b02_w_2), docplex.mp.MonomialExpr(126x_b02_w_3), docplex.mp.MonomialExpr(140x_b02_w_4), docplex.mp.MonomialExpr(154x_b02_w_5), docplex.mp.MonomialExpr(170x_b02_w_6), docplex.mp.MonomialExpr(184x_b02_w_7), docplex.mp.MonomialExpr(199x_b02_w_8), docplex.mp.MonomialExpr(59x_b14_w_1), docplex.mp.MonomialExpr(74x_b14_w_2), docplex.mp.MonomialExpr(88x_b14_w_3), docplex.mp.MonomialExpr(104x_b14_w_4), docplex.mp.MonomialExpr(119x_b14_w_5), docplex.mp.MonomialExpr(134x_b14_w_6), docplex.mp.MonomialExpr(148x_b14_w_7), docplex.mp.MonomialExpr(162x_b14_w_8), docplex.mp.MonomialExpr(41x_b31_w_1), docplex.mp.MonomialExpr(56x_b31_w_2), docplex.mp.MonomialExpr(71x_b31_w_3), docplex.mp.MonomialExpr(86x_b31_w_4), docplex.mp.MonomialExpr(101x_b31_w_5), docplex.mp.MonomialExpr(116x_b31_w_6), docplex.mp.MonomialExpr(130x_b31_w_7), docplex.mp.MonomialExpr(145x_b31_w_8), docplex.mp.MonomialExpr(44x_b37_w_1), docplex.mp.MonomialExpr(59x_b37_w_2), docplex.mp.MonomialExpr(75x_b37_w_3), docplex.mp.MonomialExpr(89x_b37_w_4), docplex.mp.MonomialExpr(104x_b37_w_5), docplex.mp.MonomialExpr(119x_b37_w_6), docplex.mp.MonomialExpr(134x_b37_w_7), docplex.mp.MonomialExpr(149x_b37_w_8), docplex.mp.MonomialExpr(71x_b39_w_1), docplex.mp.MonomialExpr(86x_b39_w_2), docplex.mp.MonomialExpr(100x_b39_w_3), docplex.mp.MonomialExpr(115x_b39_w_4), docplex.mp.MonomialExpr(131x_b39_w_5), docplex.mp.MonomialExpr(144x_b39_w_6), docplex.mp.MonomialExpr(158x_b39_w_7), docplex.mp.MonomialExpr(173x_b39_w_8)]
# Threshold constraint for 1047: max_gap_threshold_1047: max_gap_1047 <= 600
# Gap constraint for 1047: max_gap_1047 == max_gap_1047
# Calculating Max Gap for stop: 1050
# Calculating gaps for stop 1050 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(94x_b02_w_1), docplex.mp.MonomialExpr(110x_b02_w_2), docplex.mp.MonomialExpr(124x_b02_w_3), docplex.mp.MonomialExpr(138x_b02_w_4), docplex.mp.MonomialExpr(152x_b02_w_5), docplex.mp.MonomialExpr(167x_b02_w_6), docplex.mp.MonomialExpr(182x_b02_w_7), docplex.mp.MonomialExpr(197x_b02_w_8), docplex.mp.MonomialExpr(57x_b14_w_1), docplex.mp.MonomialExpr(71x_b14_w_2), docplex.mp.MonomialExpr(86x_b14_w_3), docplex.mp.MonomialExpr(101x_b14_w_4), docplex.mp.MonomialExpr(116x_b14_w_5), docplex.mp.MonomialExpr(131x_b14_w_6), docplex.mp.MonomialExpr(146x_b14_w_7), docplex.mp.MonomialExpr(160x_b14_w_8), docplex.mp.MonomialExpr(38x_b31_w_1), docplex.mp.MonomialExpr(53x_b31_w_2), docplex.mp.MonomialExpr(68x_b31_w_3), docplex.mp.MonomialExpr(83x_b31_w_4), docplex.mp.MonomialExpr(99x_b31_w_5), docplex.mp.MonomialExpr(114x_b31_w_6), docplex.mp.MonomialExpr(128x_b31_w_7), docplex.mp.MonomialExpr(143x_b31_w_8), docplex.mp.MonomialExpr(42x_b37_w_1), docplex.mp.MonomialExpr(57x_b37_w_2), docplex.mp.MonomialExpr(72x_b37_w_3), docplex.mp.MonomialExpr(87x_b37_w_4), docplex.mp.MonomialExpr(102x_b37_w_5), docplex.mp.MonomialExpr(117x_b37_w_6), docplex.mp.MonomialExpr(132x_b37_w_7), docplex.mp.MonomialExpr(147x_b37_w_8), docplex.mp.MonomialExpr(68x_b39_w_1), docplex.mp.MonomialExpr(84x_b39_w_2), docplex.mp.MonomialExpr(97x_b39_w_3), docplex.mp.MonomialExpr(113x_b39_w_4), docplex.mp.MonomialExpr(129x_b39_w_5), docplex.mp.MonomialExpr(142x_b39_w_6), docplex.mp.MonomialExpr(156x_b39_w_7), docplex.mp.MonomialExpr(171x_b39_w_8)]
# Threshold constraint for 1050: max_gap_threshold_1050: max_gap_1050 <= 600
# Gap constraint for 1050: max_gap_1050 == max_gap_1050
# Calculating Max Gap for stop: 1051
# Calculating gaps for stop 1051 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(91x_b02_w_1), docplex.mp.MonomialExpr(107x_b02_w_2), docplex.mp.MonomialExpr(121x_b02_w_3), docplex.mp.MonomialExpr(136x_b02_w_4), docplex.mp.MonomialExpr(149x_b02_w_5), docplex.mp.MonomialExpr(164x_b02_w_6), docplex.mp.MonomialExpr(179x_b02_w_7), docplex.mp.MonomialExpr(194x_b02_w_8), docplex.mp.MonomialExpr(54x_b14_w_1), docplex.mp.MonomialExpr(68x_b14_w_2), docplex.mp.MonomialExpr(83x_b14_w_3), docplex.mp.MonomialExpr(98x_b14_w_4), docplex.mp.MonomialExpr(114x_b14_w_5), docplex.mp.MonomialExpr(128x_b14_w_6), docplex.mp.MonomialExpr(143x_b14_w_7), docplex.mp.MonomialExpr(157x_b14_w_8), docplex.mp.MonomialExpr(35x_b31_w_1), docplex.mp.MonomialExpr(50x_b31_w_2), docplex.mp.MonomialExpr(65x_b31_w_3), docplex.mp.MonomialExpr(80x_b31_w_4), docplex.mp.MonomialExpr(96x_b31_w_5), docplex.mp.MonomialExpr(111x_b31_w_6), docplex.mp.MonomialExpr(125x_b31_w_7), docplex.mp.MonomialExpr(140x_b31_w_8), docplex.mp.MonomialExpr(39x_b37_w_1), docplex.mp.MonomialExpr(54x_b37_w_2), docplex.mp.MonomialExpr(69x_b37_w_3), docplex.mp.MonomialExpr(84x_b37_w_4), docplex.mp.MonomialExpr(99x_b37_w_5), docplex.mp.MonomialExpr(114x_b37_w_6), docplex.mp.MonomialExpr(129x_b37_w_7), docplex.mp.MonomialExpr(144x_b37_w_8), docplex.mp.MonomialExpr(65x_b39_w_1), docplex.mp.MonomialExpr(81x_b39_w_2), docplex.mp.MonomialExpr(94x_b39_w_3), docplex.mp.MonomialExpr(110x_b39_w_4), docplex.mp.MonomialExpr(126x_b39_w_5), docplex.mp.MonomialExpr(139x_b39_w_6), docplex.mp.MonomialExpr(153x_b39_w_7), docplex.mp.MonomialExpr(168x_b39_w_8)]
# Threshold constraint for 1051: max_gap_threshold_1051: max_gap_1051 <= 600
# Gap constraint for 1051: max_gap_1051 == max_gap_1051
# Calculating Max Gap for stop: 1054
# Calculating gaps for stop 1054 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(36x_b37_w_1), docplex.mp.MonomialExpr(51x_b37_w_2), docplex.mp.MonomialExpr(66x_b37_w_3), docplex.mp.MonomialExpr(81x_b37_w_4), docplex.mp.MonomialExpr(96x_b37_w_5), docplex.mp.MonomialExpr(111x_b37_w_6), docplex.mp.MonomialExpr(126x_b37_w_7), docplex.mp.MonomialExpr(141x_b37_w_8)]
# Threshold constraint for 1054: max_gap_threshold_1054: max_gap_1054 <= 600
# Gap constraint for 1054: max_gap_1054 == max_gap_1054
# Calculating Max Gap for stop: 1114
# Calculating gaps for stop 1114 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(73x_b05_w_1), docplex.mp.MonomialExpr(87x_b05_w_2), docplex.mp.MonomialExpr(103x_b05_w_3), docplex.mp.MonomialExpr(118x_b05_w_4), docplex.mp.MonomialExpr(132x_b05_w_5), docplex.mp.MonomialExpr(146x_b05_w_6), docplex.mp.MonomialExpr(161x_b05_w_7), docplex.mp.MonomialExpr(176x_b05_w_8), docplex.mp.MonomialExpr(71x_b06_w_1), docplex.mp.MonomialExpr(85x_b06_w_2), docplex.mp.MonomialExpr(101x_b06_w_3), docplex.mp.MonomialExpr(117x_b06_w_4), docplex.mp.MonomialExpr(130x_b06_w_5), docplex.mp.MonomialExpr(144x_b06_w_6), docplex.mp.MonomialExpr(159x_b06_w_7), docplex.mp.MonomialExpr(174x_b06_w_8), docplex.mp.MonomialExpr(76x_b33_w_1), docplex.mp.MonomialExpr(91x_b33_w_2), docplex.mp.MonomialExpr(108x_b33_w_3), docplex.mp.MonomialExpr(121x_b33_w_4), docplex.mp.MonomialExpr(135x_b33_w_5), docplex.mp.MonomialExpr(150x_b33_w_6), docplex.mp.MonomialExpr(165x_b33_w_7), docplex.mp.MonomialExpr(179x_b33_w_8), docplex.mp.MonomialExpr(56x_b39_w_1), docplex.mp.MonomialExpr(72x_b39_w_2), docplex.mp.MonomialExpr(85x_b39_w_3), docplex.mp.MonomialExpr(101x_b39_w_4), docplex.mp.MonomialExpr(117x_b39_w_5), docplex.mp.MonomialExpr(130x_b39_w_6), docplex.mp.MonomialExpr(144x_b39_w_7), docplex.mp.MonomialExpr(159x_b39_w_8)]
# Threshold constraint for 1114: max_gap_threshold_1114: max_gap_1114 <= 600
# Gap constraint for 1114: max_gap_1114 == max_gap_1114
# Calculating Max Gap for stop: 1115
# Calculating gaps for stop 1115 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(88x_b07_w_1), docplex.mp.MonomialExpr(104x_b07_w_2), docplex.mp.MonomialExpr(119x_b07_w_3), docplex.mp.MonomialExpr(133x_b07_w_4), docplex.mp.MonomialExpr(148x_b07_w_5), docplex.mp.MonomialExpr(163x_b07_w_6), docplex.mp.MonomialExpr(178x_b07_w_7), docplex.mp.MonomialExpr(192x_b07_w_8), docplex.mp.MonomialExpr(32x_b31_w_1), docplex.mp.MonomialExpr(47x_b31_w_2), docplex.mp.MonomialExpr(62x_b31_w_3), docplex.mp.MonomialExpr(78x_b31_w_4), docplex.mp.MonomialExpr(93x_b31_w_5), docplex.mp.MonomialExpr(108x_b31_w_6), docplex.mp.MonomialExpr(122x_b31_w_7), docplex.mp.MonomialExpr(137x_b31_w_8), docplex.mp.MonomialExpr(62x_b39_w_1), docplex.mp.MonomialExpr(78x_b39_w_2), docplex.mp.MonomialExpr(92x_b39_w_3), docplex.mp.MonomialExpr(107x_b39_w_4), docplex.mp.MonomialExpr(123x_b39_w_5), docplex.mp.MonomialExpr(136x_b39_w_6), docplex.mp.MonomialExpr(150x_b39_w_7), docplex.mp.MonomialExpr(165x_b39_w_8)]
# Threshold constraint for 1115: max_gap_threshold_1115: max_gap_1115 <= 600
# Gap constraint for 1115: max_gap_1115 == max_gap_1115
# Calculating Max Gap for stop: 1120
# Calculating gaps for stop 1120 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(85x_b07_w_1), docplex.mp.MonomialExpr(101x_b07_w_2), docplex.mp.MonomialExpr(117x_b07_w_3), docplex.mp.MonomialExpr(131x_b07_w_4), docplex.mp.MonomialExpr(145x_b07_w_5), docplex.mp.MonomialExpr(160x_b07_w_6), docplex.mp.MonomialExpr(175x_b07_w_7), docplex.mp.MonomialExpr(189x_b07_w_8), docplex.mp.MonomialExpr(38x_b10_w_1), docplex.mp.MonomialExpr(54x_b10_w_2), docplex.mp.MonomialExpr(68x_b10_w_3), docplex.mp.MonomialExpr(83x_b10_w_4), docplex.mp.MonomialExpr(99x_b10_w_5), docplex.mp.MonomialExpr(115x_b10_w_6), docplex.mp.MonomialExpr(129x_b10_w_7), docplex.mp.MonomialExpr(143x_b10_w_8), docplex.mp.MonomialExpr(39x_b12_w_1), docplex.mp.MonomialExpr(54x_b12_w_2), docplex.mp.MonomialExpr(69x_b12_w_3), docplex.mp.MonomialExpr(84x_b12_w_4), docplex.mp.MonomialExpr(99x_b12_w_5), docplex.mp.MonomialExpr(114x_b12_w_6), docplex.mp.MonomialExpr(129x_b12_w_7), docplex.mp.MonomialExpr(143x_b12_w_8), docplex.mp.MonomialExpr(29x_b31_w_1), docplex.mp.MonomialExpr(44x_b31_w_2), docplex.mp.MonomialExpr(60x_b31_w_3), docplex.mp.MonomialExpr(75x_b31_w_4), docplex.mp.MonomialExpr(90x_b31_w_5), docplex.mp.MonomialExpr(105x_b31_w_6), docplex.mp.MonomialExpr(120x_b31_w_7), docplex.mp.MonomialExpr(134x_b31_w_8)]
# Threshold constraint for 1120: max_gap_threshold_1120: max_gap_1120 <= 600
# Gap constraint for 1120: max_gap_1120 == max_gap_1120
# Calculating Max Gap for stop: 1122
# Calculating gaps for stop 1122 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(82x_b07_w_1), docplex.mp.MonomialExpr(98x_b07_w_2), docplex.mp.MonomialExpr(114x_b07_w_3), docplex.mp.MonomialExpr(128x_b07_w_4), docplex.mp.MonomialExpr(142x_b07_w_5), docplex.mp.MonomialExpr(157x_b07_w_6), docplex.mp.MonomialExpr(172x_b07_w_7), docplex.mp.MonomialExpr(186x_b07_w_8), docplex.mp.MonomialExpr(35x_b10_w_1), docplex.mp.MonomialExpr(51x_b10_w_2), docplex.mp.MonomialExpr(65x_b10_w_3), docplex.mp.MonomialExpr(80x_b10_w_4), docplex.mp.MonomialExpr(96x_b10_w_5), docplex.mp.MonomialExpr(112x_b10_w_6), docplex.mp.MonomialExpr(126x_b10_w_7), docplex.mp.MonomialExpr(140x_b10_w_8), docplex.mp.MonomialExpr(36x_b12_w_1), docplex.mp.MonomialExpr(51x_b12_w_2), docplex.mp.MonomialExpr(66x_b12_w_3), docplex.mp.MonomialExpr(81x_b12_w_4), docplex.mp.MonomialExpr(96x_b12_w_5), docplex.mp.MonomialExpr(111x_b12_w_6), docplex.mp.MonomialExpr(126x_b12_w_7), docplex.mp.MonomialExpr(140x_b12_w_8), docplex.mp.MonomialExpr(26x_b31_w_1), docplex.mp.MonomialExpr(41x_b31_w_2), docplex.mp.MonomialExpr(57x_b31_w_3), docplex.mp.MonomialExpr(72x_b31_w_4), docplex.mp.MonomialExpr(87x_b31_w_5), docplex.mp.MonomialExpr(102x_b31_w_6), docplex.mp.MonomialExpr(117x_b31_w_7), docplex.mp.MonomialExpr(131x_b31_w_8)]
# Threshold constraint for 1122: max_gap_threshold_1122: max_gap_1122 <= 600
# Gap constraint for 1122: max_gap_1122 == max_gap_1122
# Calculating Max Gap for stop: 1125
# Calculating gaps for stop 1125 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(79x_b07_w_1), docplex.mp.MonomialExpr(95x_b07_w_2), docplex.mp.MonomialExpr(111x_b07_w_3), docplex.mp.MonomialExpr(125x_b07_w_4), docplex.mp.MonomialExpr(139x_b07_w_5), docplex.mp.MonomialExpr(154x_b07_w_6), docplex.mp.MonomialExpr(169x_b07_w_7), docplex.mp.MonomialExpr(184x_b07_w_8), docplex.mp.MonomialExpr(33x_b10_w_1), docplex.mp.MonomialExpr(48x_b10_w_2), docplex.mp.MonomialExpr(63x_b10_w_3), docplex.mp.MonomialExpr(77x_b10_w_4), docplex.mp.MonomialExpr(93x_b10_w_5), docplex.mp.MonomialExpr(109x_b10_w_6), docplex.mp.MonomialExpr(124x_b10_w_7), docplex.mp.MonomialExpr(137x_b10_w_8), docplex.mp.MonomialExpr(23x_b31_w_1), docplex.mp.MonomialExpr(39x_b31_w_2), docplex.mp.MonomialExpr(54x_b31_w_3), docplex.mp.MonomialExpr(69x_b31_w_4), docplex.mp.MonomialExpr(84x_b31_w_5), docplex.mp.MonomialExpr(99x_b31_w_6), docplex.mp.MonomialExpr(114x_b31_w_7), docplex.mp.MonomialExpr(129x_b31_w_8)]
# Threshold constraint for 1125: max_gap_threshold_1125: max_gap_1125 <= 600
# Gap constraint for 1125: max_gap_1125 == max_gap_1125
# Calculating Max Gap for stop: 1127
# Calculating gaps for stop 1127 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(33x_b12_w_1), docplex.mp.MonomialExpr(48x_b12_w_2), docplex.mp.MonomialExpr(63x_b12_w_3), docplex.mp.MonomialExpr(78x_b12_w_4), docplex.mp.MonomialExpr(93x_b12_w_5), docplex.mp.MonomialExpr(108x_b12_w_6), docplex.mp.MonomialExpr(123x_b12_w_7), docplex.mp.MonomialExpr(137x_b12_w_8)]
# Threshold constraint for 1127: max_gap_threshold_1127: max_gap_1127 <= 600
# Gap constraint for 1127: max_gap_1127 == max_gap_1127
# Calculating Max Gap for stop: 1128
# Calculating gaps for stop 1128 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(30x_b12_w_1), docplex.mp.MonomialExpr(45x_b12_w_2), docplex.mp.MonomialExpr(60x_b12_w_3), docplex.mp.MonomialExpr(75x_b12_w_4), docplex.mp.MonomialExpr(90x_b12_w_5), docplex.mp.MonomialExpr(105x_b12_w_6), docplex.mp.MonomialExpr(120x_b12_w_7), docplex.mp.MonomialExpr(135x_b12_w_8)]
# Threshold constraint for 1128: max_gap_threshold_1128: max_gap_1128 <= 600
# Gap constraint for 1128: max_gap_1128 == max_gap_1128
# Calculating Max Gap for stop: 1130
# Calculating gaps for stop 1130 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(74x_b02_w_1), docplex.mp.MonomialExpr(90x_b02_w_2), docplex.mp.MonomialExpr(104x_b02_w_3), docplex.mp.MonomialExpr(119x_b02_w_4), docplex.mp.MonomialExpr(133x_b02_w_5), docplex.mp.MonomialExpr(148x_b02_w_6), docplex.mp.MonomialExpr(163x_b02_w_7), docplex.mp.MonomialExpr(178x_b02_w_8), docplex.mp.MonomialExpr(36x_b14_w_1), docplex.mp.MonomialExpr(51x_b14_w_2), docplex.mp.MonomialExpr(66x_b14_w_3), docplex.mp.MonomialExpr(81x_b14_w_4), docplex.mp.MonomialExpr(97x_b14_w_5), docplex.mp.MonomialExpr(112x_b14_w_6), docplex.mp.MonomialExpr(127x_b14_w_7), docplex.mp.MonomialExpr(141x_b14_w_8)]
# Threshold constraint for 1130: max_gap_threshold_1130: max_gap_1130 <= 600
# Gap constraint for 1130: max_gap_1130 == max_gap_1130
# Calculating Max Gap for stop: 1132
# Calculating gaps for stop 1132 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(77x_b02_w_1), docplex.mp.MonomialExpr(92x_b02_w_2), docplex.mp.MonomialExpr(106x_b02_w_3), docplex.mp.MonomialExpr(121x_b02_w_4), docplex.mp.MonomialExpr(135x_b02_w_5), docplex.mp.MonomialExpr(150x_b02_w_6), docplex.mp.MonomialExpr(165x_b02_w_7), docplex.mp.MonomialExpr(180x_b02_w_8), docplex.mp.MonomialExpr(39x_b14_w_1), docplex.mp.MonomialExpr(54x_b14_w_2), docplex.mp.MonomialExpr(69x_b14_w_3), docplex.mp.MonomialExpr(84x_b14_w_4), docplex.mp.MonomialExpr(99x_b14_w_5), docplex.mp.MonomialExpr(114x_b14_w_6), docplex.mp.MonomialExpr(129x_b14_w_7), docplex.mp.MonomialExpr(143x_b14_w_8)]
# Threshold constraint for 1132: max_gap_threshold_1132: max_gap_1132 <= 600
# Gap constraint for 1132: max_gap_1132 == max_gap_1132
# Calculating Max Gap for stop: 1137
# Calculating gaps for stop 1137 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(82x_b02_w_1), docplex.mp.MonomialExpr(97x_b02_w_2), docplex.mp.MonomialExpr(111x_b02_w_3), docplex.mp.MonomialExpr(126x_b02_w_4), docplex.mp.MonomialExpr(140x_b02_w_5), docplex.mp.MonomialExpr(155x_b02_w_6), docplex.mp.MonomialExpr(170x_b02_w_7), docplex.mp.MonomialExpr(185x_b02_w_8), docplex.mp.MonomialExpr(44x_b14_w_1), docplex.mp.MonomialExpr(59x_b14_w_2), docplex.mp.MonomialExpr(73x_b14_w_3), docplex.mp.MonomialExpr(88x_b14_w_4), docplex.mp.MonomialExpr(104x_b14_w_5), docplex.mp.MonomialExpr(119x_b14_w_6), docplex.mp.MonomialExpr(134x_b14_w_7), docplex.mp.MonomialExpr(148x_b14_w_8)]
# Threshold constraint for 1137: max_gap_threshold_1137: max_gap_1137 <= 600
# Gap constraint for 1137: max_gap_1137 == max_gap_1137
# Calculating Max Gap for stop: 1138
# Calculating gaps for stop 1138 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(84x_b02_w_1), docplex.mp.MonomialExpr(100x_b02_w_2), docplex.mp.MonomialExpr(114x_b02_w_3), docplex.mp.MonomialExpr(128x_b02_w_4), docplex.mp.MonomialExpr(142x_b02_w_5), docplex.mp.MonomialExpr(158x_b02_w_6), docplex.mp.MonomialExpr(172x_b02_w_7), docplex.mp.MonomialExpr(187x_b02_w_8), docplex.mp.MonomialExpr(47x_b14_w_1), docplex.mp.MonomialExpr(61x_b14_w_2), docplex.mp.MonomialExpr(76x_b14_w_3), docplex.mp.MonomialExpr(91x_b14_w_4), docplex.mp.MonomialExpr(107x_b14_w_5), docplex.mp.MonomialExpr(121x_b14_w_6), docplex.mp.MonomialExpr(136x_b14_w_7), docplex.mp.MonomialExpr(150x_b14_w_8)]
# Threshold constraint for 1138: max_gap_threshold_1138: max_gap_1138 <= 600
# Gap constraint for 1138: max_gap_1138 == max_gap_1138
# Calculating Max Gap for stop: 1141
# Calculating gaps for stop 1141 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(91x_b07_w_1), docplex.mp.MonomialExpr(106x_b07_w_2), docplex.mp.MonomialExpr(122x_b07_w_3), docplex.mp.MonomialExpr(136x_b07_w_4), docplex.mp.MonomialExpr(150x_b07_w_5), docplex.mp.MonomialExpr(165x_b07_w_6), docplex.mp.MonomialExpr(180x_b07_w_7), docplex.mp.MonomialExpr(195x_b07_w_8)]
# Threshold constraint for 1141: max_gap_threshold_1141: max_gap_1141 <= 600
# Gap constraint for 1141: max_gap_1141 == max_gap_1141
# Calculating Max Gap for stop: 1142
# Calculating gaps for stop 1142 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(87x_b02_w_1), docplex.mp.MonomialExpr(103x_b02_w_2), docplex.mp.MonomialExpr(117x_b02_w_3), docplex.mp.MonomialExpr(132x_b02_w_4), docplex.mp.MonomialExpr(145x_b02_w_5), docplex.mp.MonomialExpr(161x_b02_w_6), docplex.mp.MonomialExpr(175x_b02_w_7), docplex.mp.MonomialExpr(190x_b02_w_8), docplex.mp.MonomialExpr(50x_b14_w_1), docplex.mp.MonomialExpr(64x_b14_w_2), docplex.mp.MonomialExpr(79x_b14_w_3), docplex.mp.MonomialExpr(94x_b14_w_4), docplex.mp.MonomialExpr(110x_b14_w_5), docplex.mp.MonomialExpr(124x_b14_w_6), docplex.mp.MonomialExpr(139x_b14_w_7), docplex.mp.MonomialExpr(153x_b14_w_8)]
# Threshold constraint for 1142: max_gap_threshold_1142: max_gap_1142 <= 600
# Gap constraint for 1142: max_gap_1142 == max_gap_1142
# Calculating Max Gap for stop: 1143
# Calculating gaps for stop 1143 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(22x_b37_w_1), docplex.mp.MonomialExpr(36x_b37_w_2), docplex.mp.MonomialExpr(52x_b37_w_3), docplex.mp.MonomialExpr(67x_b37_w_4), docplex.mp.MonomialExpr(82x_b37_w_5), docplex.mp.MonomialExpr(97x_b37_w_6), docplex.mp.MonomialExpr(112x_b37_w_7), docplex.mp.MonomialExpr(127x_b37_w_8)]
# Threshold constraint for 1143: max_gap_threshold_1143: max_gap_1143 <= 600
# Gap constraint for 1143: max_gap_1143 == max_gap_1143
# Calculating Max Gap for stop: 1145
# Calculating gaps for stop 1145 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(24x_b37_w_1), docplex.mp.MonomialExpr(39x_b37_w_2), docplex.mp.MonomialExpr(55x_b37_w_3), docplex.mp.MonomialExpr(70x_b37_w_4), docplex.mp.MonomialExpr(85x_b37_w_5), docplex.mp.MonomialExpr(100x_b37_w_6), docplex.mp.MonomialExpr(115x_b37_w_7), docplex.mp.MonomialExpr(130x_b37_w_8)]
# Threshold constraint for 1145: max_gap_threshold_1145: max_gap_1145 <= 600
# Gap constraint for 1145: max_gap_1145 == max_gap_1145
# Calculating Max Gap for stop: 1147
# Calculating gaps for stop 1147 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(28x_b37_w_1), docplex.mp.MonomialExpr(42x_b37_w_2), docplex.mp.MonomialExpr(58x_b37_w_3), docplex.mp.MonomialExpr(73x_b37_w_4), docplex.mp.MonomialExpr(88x_b37_w_5), docplex.mp.MonomialExpr(103x_b37_w_6), docplex.mp.MonomialExpr(118x_b37_w_7), docplex.mp.MonomialExpr(133x_b37_w_8)]
# Threshold constraint for 1147: max_gap_threshold_1147: max_gap_1147 <= 600
# Gap constraint for 1147: max_gap_1147 == max_gap_1147
# Calculating Max Gap for stop: 1148
# Calculating gaps for stop 1148 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(30x_b37_w_1), docplex.mp.MonomialExpr(45x_b37_w_2), docplex.mp.MonomialExpr(61x_b37_w_3), docplex.mp.MonomialExpr(76x_b37_w_4), docplex.mp.MonomialExpr(91x_b37_w_5), docplex.mp.MonomialExpr(106x_b37_w_6), docplex.mp.MonomialExpr(121x_b37_w_7), docplex.mp.MonomialExpr(136x_b37_w_8)]
# Threshold constraint for 1148: max_gap_threshold_1148: max_gap_1148 <= 600
# Gap constraint for 1148: max_gap_1148 == max_gap_1148
# Calculating Max Gap for stop: 1157
# Calculating gaps for stop 1157 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(78x_b05_w_1), docplex.mp.MonomialExpr(93x_b05_w_2), docplex.mp.MonomialExpr(109x_b05_w_3), docplex.mp.MonomialExpr(124x_b05_w_4), docplex.mp.MonomialExpr(137x_b05_w_5), docplex.mp.MonomialExpr(151x_b05_w_6), docplex.mp.MonomialExpr(167x_b05_w_7), docplex.mp.MonomialExpr(181x_b05_w_8), docplex.mp.MonomialExpr(76x_b06_w_1), docplex.mp.MonomialExpr(91x_b06_w_2), docplex.mp.MonomialExpr(107x_b06_w_3), docplex.mp.MonomialExpr(123x_b06_w_4), docplex.mp.MonomialExpr(135x_b06_w_5), docplex.mp.MonomialExpr(149x_b06_w_6), docplex.mp.MonomialExpr(165x_b06_w_7), docplex.mp.MonomialExpr(180x_b06_w_8), docplex.mp.MonomialExpr(41x_b10_w_1), docplex.mp.MonomialExpr(57x_b10_w_2), docplex.mp.MonomialExpr(71x_b10_w_3), docplex.mp.MonomialExpr(86x_b10_w_4), docplex.mp.MonomialExpr(102x_b10_w_5), docplex.mp.MonomialExpr(117x_b10_w_6), docplex.mp.MonomialExpr(132x_b10_w_7), docplex.mp.MonomialExpr(146x_b10_w_8), docplex.mp.MonomialExpr(42x_b12_w_1), docplex.mp.MonomialExpr(57x_b12_w_2), docplex.mp.MonomialExpr(72x_b12_w_3), docplex.mp.MonomialExpr(87x_b12_w_4), docplex.mp.MonomialExpr(102x_b12_w_5), docplex.mp.MonomialExpr(117x_b12_w_6), docplex.mp.MonomialExpr(131x_b12_w_7), docplex.mp.MonomialExpr(146x_b12_w_8), docplex.mp.MonomialExpr(82x_b33_w_1), docplex.mp.MonomialExpr(97x_b33_w_2), docplex.mp.MonomialExpr(114x_b33_w_3), docplex.mp.MonomialExpr(127x_b33_w_4), docplex.mp.MonomialExpr(141x_b33_w_5), docplex.mp.MonomialExpr(155x_b33_w_6), docplex.mp.MonomialExpr(171x_b33_w_7), docplex.mp.MonomialExpr(185x_b33_w_8)]
# Threshold constraint for 1157: max_gap_threshold_1157: max_gap_1157 <= 600
# Gap constraint for 1157: max_gap_1157 == max_gap_1157
# Calculating Max Gap for stop: 1158
# Calculating gaps for stop 1158 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(81x_b05_w_1), docplex.mp.MonomialExpr(96x_b05_w_2), docplex.mp.MonomialExpr(112x_b05_w_3), docplex.mp.MonomialExpr(127x_b05_w_4), docplex.mp.MonomialExpr(140x_b05_w_5), docplex.mp.MonomialExpr(154x_b05_w_6), docplex.mp.MonomialExpr(170x_b05_w_7), docplex.mp.MonomialExpr(184x_b05_w_8), docplex.mp.MonomialExpr(79x_b06_w_1), docplex.mp.MonomialExpr(93x_b06_w_2), docplex.mp.MonomialExpr(109x_b06_w_3), docplex.mp.MonomialExpr(126x_b06_w_4), docplex.mp.MonomialExpr(138x_b06_w_5), docplex.mp.MonomialExpr(152x_b06_w_6), docplex.mp.MonomialExpr(168x_b06_w_7), docplex.mp.MonomialExpr(182x_b06_w_8), docplex.mp.MonomialExpr(44x_b10_w_1), docplex.mp.MonomialExpr(59x_b10_w_2), docplex.mp.MonomialExpr(74x_b10_w_3), docplex.mp.MonomialExpr(89x_b10_w_4), docplex.mp.MonomialExpr(104x_b10_w_5), docplex.mp.MonomialExpr(120x_b10_w_6), docplex.mp.MonomialExpr(134x_b10_w_7), docplex.mp.MonomialExpr(148x_b10_w_8), docplex.mp.MonomialExpr(45x_b12_w_1), docplex.mp.MonomialExpr(60x_b12_w_2), docplex.mp.MonomialExpr(75x_b12_w_3), docplex.mp.MonomialExpr(89x_b12_w_4), docplex.mp.MonomialExpr(104x_b12_w_5), docplex.mp.MonomialExpr(119x_b12_w_6), docplex.mp.MonomialExpr(134x_b12_w_7), docplex.mp.MonomialExpr(148x_b12_w_8), docplex.mp.MonomialExpr(85x_b33_w_1), docplex.mp.MonomialExpr(100x_b33_w_2), docplex.mp.MonomialExpr(117x_b33_w_3), docplex.mp.MonomialExpr(130x_b33_w_4), docplex.mp.MonomialExpr(144x_b33_w_5), docplex.mp.MonomialExpr(158x_b33_w_6), docplex.mp.MonomialExpr(174x_b33_w_7), docplex.mp.MonomialExpr(187x_b33_w_8)]
# Threshold constraint for 1158: max_gap_threshold_1158: max_gap_1158 <= 600
# Gap constraint for 1158: max_gap_1158 == max_gap_1158
# Calculating Max Gap for stop: 1166
# Calculating gaps for stop 1166 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(75x_b05_w_1), docplex.mp.MonomialExpr(90x_b05_w_2), docplex.mp.MonomialExpr(106x_b05_w_3), docplex.mp.MonomialExpr(121x_b05_w_4), docplex.mp.MonomialExpr(134x_b05_w_5), docplex.mp.MonomialExpr(148x_b05_w_6), docplex.mp.MonomialExpr(164x_b05_w_7), docplex.mp.MonomialExpr(178x_b05_w_8), docplex.mp.MonomialExpr(73x_b06_w_1), docplex.mp.MonomialExpr(88x_b06_w_2), docplex.mp.MonomialExpr(104x_b06_w_3), docplex.mp.MonomialExpr(120x_b06_w_4), docplex.mp.MonomialExpr(133x_b06_w_5), docplex.mp.MonomialExpr(147x_b06_w_6), docplex.mp.MonomialExpr(162x_b06_w_7), docplex.mp.MonomialExpr(177x_b06_w_8), docplex.mp.MonomialExpr(79x_b33_w_1), docplex.mp.MonomialExpr(94x_b33_w_2), docplex.mp.MonomialExpr(111x_b33_w_3), docplex.mp.MonomialExpr(124x_b33_w_4), docplex.mp.MonomialExpr(138x_b33_w_5), docplex.mp.MonomialExpr(153x_b33_w_6), docplex.mp.MonomialExpr(168x_b33_w_7), docplex.mp.MonomialExpr(182x_b33_w_8), docplex.mp.MonomialExpr(59x_b39_w_1), docplex.mp.MonomialExpr(74x_b39_w_2), docplex.mp.MonomialExpr(88x_b39_w_3), docplex.mp.MonomialExpr(104x_b39_w_4), docplex.mp.MonomialExpr(120x_b39_w_5), docplex.mp.MonomialExpr(133x_b39_w_6), docplex.mp.MonomialExpr(147x_b39_w_7), docplex.mp.MonomialExpr(162x_b39_w_8)]
# Threshold constraint for 1166: max_gap_threshold_1166: max_gap_1166 <= 600
# Gap constraint for 1166: max_gap_1166 == max_gap_1166
# Calculating Max Gap for stop: 1167
# Calculating gaps for stop 1167 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(30x_b10_w_1), docplex.mp.MonomialExpr(45x_b10_w_2), docplex.mp.MonomialExpr(60x_b10_w_3), docplex.mp.MonomialExpr(75x_b10_w_4), docplex.mp.MonomialExpr(90x_b10_w_5), docplex.mp.MonomialExpr(106x_b10_w_6), docplex.mp.MonomialExpr(121x_b10_w_7), docplex.mp.MonomialExpr(135x_b10_w_8)]
# Threshold constraint for 1167: max_gap_threshold_1167: max_gap_1167 <= 600
# Gap constraint for 1167: max_gap_1167 == max_gap_1167
# Calculating Max Gap for stop: 1170
# Calculating gaps for stop 1170 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(25x_b10_w_1), docplex.mp.MonomialExpr(41x_b10_w_2), docplex.mp.MonomialExpr(56x_b10_w_3), docplex.mp.MonomialExpr(71x_b10_w_4), docplex.mp.MonomialExpr(86x_b10_w_5), docplex.mp.MonomialExpr(101x_b10_w_6), docplex.mp.MonomialExpr(117x_b10_w_7), docplex.mp.MonomialExpr(130x_b10_w_8)]
# Threshold constraint for 1170: max_gap_threshold_1170: max_gap_1170 <= 600
# Gap constraint for 1170: max_gap_1170 == max_gap_1170
# Calculating Max Gap for stop: 1171
# Calculating gaps for stop 1171 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(22x_b10_w_1), docplex.mp.MonomialExpr(37x_b10_w_2), docplex.mp.MonomialExpr(52x_b10_w_3), docplex.mp.MonomialExpr(67x_b10_w_4), docplex.mp.MonomialExpr(82x_b10_w_5), docplex.mp.MonomialExpr(98x_b10_w_6), docplex.mp.MonomialExpr(113x_b10_w_7), docplex.mp.MonomialExpr(127x_b10_w_8)]
# Threshold constraint for 1171: max_gap_threshold_1171: max_gap_1171 <= 600
# Gap constraint for 1171: max_gap_1171 == max_gap_1171
# Calculating Max Gap for stop: 1173
# Calculating gaps for stop 1173 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(19x_b10_w_1), docplex.mp.MonomialExpr(34x_b10_w_2), docplex.mp.MonomialExpr(49x_b10_w_3), docplex.mp.MonomialExpr(64x_b10_w_4), docplex.mp.MonomialExpr(79x_b10_w_5), docplex.mp.MonomialExpr(94x_b10_w_6), docplex.mp.MonomialExpr(109x_b10_w_7), docplex.mp.MonomialExpr(124x_b10_w_8)]
# Threshold constraint for 1173: max_gap_threshold_1173: max_gap_1173 <= 600
# Gap constraint for 1173: max_gap_1173 == max_gap_1173
# Calculating Max Gap for stop: 1176
# Calculating gaps for stop 1176 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(20x_b31_w_1), docplex.mp.MonomialExpr(35x_b31_w_2), docplex.mp.MonomialExpr(50x_b31_w_3), docplex.mp.MonomialExpr(66x_b31_w_4), docplex.mp.MonomialExpr(81x_b31_w_5), docplex.mp.MonomialExpr(96x_b31_w_6), docplex.mp.MonomialExpr(111x_b31_w_7), docplex.mp.MonomialExpr(125x_b31_w_8)]
# Threshold constraint for 1176: max_gap_threshold_1176: max_gap_1176 <= 600
# Gap constraint for 1176: max_gap_1176 == max_gap_1176
# Calculating Max Gap for stop: 1177
# Calculating gaps for stop 1177 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(17x_b31_w_1), docplex.mp.MonomialExpr(32x_b31_w_2), docplex.mp.MonomialExpr(47x_b31_w_3), docplex.mp.MonomialExpr(63x_b31_w_4), docplex.mp.MonomialExpr(78x_b31_w_5), docplex.mp.MonomialExpr(93x_b31_w_6), docplex.mp.MonomialExpr(108x_b31_w_7), docplex.mp.MonomialExpr(123x_b31_w_8)]
# Threshold constraint for 1177: max_gap_threshold_1177: max_gap_1177 <= 600
# Gap constraint for 1177: max_gap_1177 == max_gap_1177
# Calculating Max Gap for stop: 1181
# Calculating gaps for stop 1181 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(11x_b31_w_1), docplex.mp.MonomialExpr(26x_b31_w_2), docplex.mp.MonomialExpr(41x_b31_w_3), docplex.mp.MonomialExpr(57x_b31_w_4), docplex.mp.MonomialExpr(72x_b31_w_5), docplex.mp.MonomialExpr(87x_b31_w_6), docplex.mp.MonomialExpr(101x_b31_w_7), docplex.mp.MonomialExpr(116x_b31_w_8)]
# Threshold constraint for 1181: max_gap_threshold_1181: max_gap_1181 <= 600
# Gap constraint for 1181: max_gap_1181 == max_gap_1181
# Calculating Max Gap for stop: 1182
# Calculating gaps for stop 1182 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(76x_b07_w_1), docplex.mp.MonomialExpr(92x_b07_w_2), docplex.mp.MonomialExpr(108x_b07_w_3), docplex.mp.MonomialExpr(122x_b07_w_4), docplex.mp.MonomialExpr(136x_b07_w_5), docplex.mp.MonomialExpr(151x_b07_w_6), docplex.mp.MonomialExpr(166x_b07_w_7), docplex.mp.MonomialExpr(181x_b07_w_8)]
# Threshold constraint for 1182: max_gap_threshold_1182: max_gap_1182 <= 600
# Gap constraint for 1182: max_gap_1182 == max_gap_1182
# Calculating Max Gap for stop: 1185
# Calculating gaps for stop 1185 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(73x_b07_w_1), docplex.mp.MonomialExpr(89x_b07_w_2), docplex.mp.MonomialExpr(105x_b07_w_3), docplex.mp.MonomialExpr(119x_b07_w_4), docplex.mp.MonomialExpr(133x_b07_w_5), docplex.mp.MonomialExpr(148x_b07_w_6), docplex.mp.MonomialExpr(163x_b07_w_7), docplex.mp.MonomialExpr(178x_b07_w_8)]
# Threshold constraint for 1185: max_gap_threshold_1185: max_gap_1185 <= 600
# Gap constraint for 1185: max_gap_1185 == max_gap_1185
# Calculating Max Gap for stop: 1186
# Calculating gaps for stop 1186 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(71x_b02_w_1), docplex.mp.MonomialExpr(87x_b02_w_2), docplex.mp.MonomialExpr(101x_b02_w_3), docplex.mp.MonomialExpr(116x_b02_w_4), docplex.mp.MonomialExpr(130x_b02_w_5), docplex.mp.MonomialExpr(145x_b02_w_6), docplex.mp.MonomialExpr(160x_b02_w_7), docplex.mp.MonomialExpr(175x_b02_w_8), docplex.mp.MonomialExpr(27x_b12_w_1), docplex.mp.MonomialExpr(42x_b12_w_2), docplex.mp.MonomialExpr(57x_b12_w_3), docplex.mp.MonomialExpr(72x_b12_w_4), docplex.mp.MonomialExpr(87x_b12_w_5), docplex.mp.MonomialExpr(102x_b12_w_6), docplex.mp.MonomialExpr(117x_b12_w_7), docplex.mp.MonomialExpr(132x_b12_w_8)]
# Threshold constraint for 1186: max_gap_threshold_1186: max_gap_1186 <= 600
# Gap constraint for 1186: max_gap_1186 == max_gap_1186
# Calculating Max Gap for stop: 1188
# Calculating gaps for stop 1188 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(68x_b02_w_1), docplex.mp.MonomialExpr(84x_b02_w_2), docplex.mp.MonomialExpr(98x_b02_w_3), docplex.mp.MonomialExpr(113x_b02_w_4), docplex.mp.MonomialExpr(127x_b02_w_5), docplex.mp.MonomialExpr(142x_b02_w_6), docplex.mp.MonomialExpr(157x_b02_w_7), docplex.mp.MonomialExpr(172x_b02_w_8)]
# Threshold constraint for 1188: max_gap_threshold_1188: max_gap_1188 <= 600
# Gap constraint for 1188: max_gap_1188 == max_gap_1188
# Calculating Max Gap for stop: 1190
# Calculating gaps for stop 1190 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(66x_b02_w_1), docplex.mp.MonomialExpr(81x_b02_w_2), docplex.mp.MonomialExpr(95x_b02_w_3), docplex.mp.MonomialExpr(110x_b02_w_4), docplex.mp.MonomialExpr(124x_b02_w_5), docplex.mp.MonomialExpr(139x_b02_w_6), docplex.mp.MonomialExpr(154x_b02_w_7), docplex.mp.MonomialExpr(170x_b02_w_8)]
# Threshold constraint for 1190: max_gap_threshold_1190: max_gap_1190 <= 600
# Gap constraint for 1190: max_gap_1190 == max_gap_1190
# Calculating Max Gap for stop: 1192
# Calculating gaps for stop 1192 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(62x_b02_w_1), docplex.mp.MonomialExpr(77x_b02_w_2), docplex.mp.MonomialExpr(92x_b02_w_3), docplex.mp.MonomialExpr(107x_b02_w_4), docplex.mp.MonomialExpr(121x_b02_w_5), docplex.mp.MonomialExpr(136x_b02_w_6), docplex.mp.MonomialExpr(151x_b02_w_7), docplex.mp.MonomialExpr(166x_b02_w_8)]
# Threshold constraint for 1192: max_gap_threshold_1192: max_gap_1192 <= 600
# Gap constraint for 1192: max_gap_1192 == max_gap_1192
# Calculating Max Gap for stop: 1194
# Calculating gaps for stop 1194 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(24x_b12_w_1), docplex.mp.MonomialExpr(39x_b12_w_2), docplex.mp.MonomialExpr(55x_b12_w_3), docplex.mp.MonomialExpr(69x_b12_w_4), docplex.mp.MonomialExpr(84x_b12_w_5), docplex.mp.MonomialExpr(100x_b12_w_6), docplex.mp.MonomialExpr(114x_b12_w_7), docplex.mp.MonomialExpr(129x_b12_w_8)]
# Threshold constraint for 1194: max_gap_threshold_1194: max_gap_1194 <= 600
# Gap constraint for 1194: max_gap_1194 == max_gap_1194
# Calculating Max Gap for stop: 1196
# Calculating gaps for stop 1196 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(22x_b12_w_1), docplex.mp.MonomialExpr(37x_b12_w_2), docplex.mp.MonomialExpr(52x_b12_w_3), docplex.mp.MonomialExpr(67x_b12_w_4), docplex.mp.MonomialExpr(82x_b12_w_5), docplex.mp.MonomialExpr(97x_b12_w_6), docplex.mp.MonomialExpr(112x_b12_w_7), docplex.mp.MonomialExpr(126x_b12_w_8)]
# Threshold constraint for 1196: max_gap_threshold_1196: max_gap_1196 <= 600
# Gap constraint for 1196: max_gap_1196 == max_gap_1196
# Calculating Max Gap for stop: 1203
# Calculating gaps for stop 1203 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(19x_b12_w_1), docplex.mp.MonomialExpr(33x_b12_w_2), docplex.mp.MonomialExpr(49x_b12_w_3), docplex.mp.MonomialExpr(64x_b12_w_4), docplex.mp.MonomialExpr(78x_b12_w_5), docplex.mp.MonomialExpr(94x_b12_w_6), docplex.mp.MonomialExpr(108x_b12_w_7), docplex.mp.MonomialExpr(123x_b12_w_8)]
# Threshold constraint for 1203: max_gap_threshold_1203: max_gap_1203 <= 600
# Gap constraint for 1203: max_gap_1203 == max_gap_1203
# Calculating Max Gap for stop: 1204
# Calculating gaps for stop 1204 with possible times: [docplex.mp.MonomialExpr(x_b00_w_1), docplex.mp.MonomialExpr(120x_b00_w_2), docplex.mp.MonomialExpr(16x_b12_w_1), docplex.mp.MonomialExpr(31x_b12_w_2), docplex.mp.MonomialExpr(46x_b12_w_3), docplex.mp.MonomialExpr(61x_b12_w_4), docplex.mp.MonomialExpr(76x_b12_w_5), docplex.mp.MonomialExpr(91x_b12_w_6), docplex.mp.MonomialExpr(106x_b12_w_7), docplex.mp.MonomialExpr(120x_b12_w_8)]
# Threshold constraint for 1204: max_gap_threshold_1204: max_gap_1204 <= 600
# Gap constraint for 1204: max_gap_1204 == max_gap_1204
# ...
#     161    59       93.5068 89321      161.4977       46.9040  1512418   70.96%
#     165    60       94.6609 87704      161.4977       46.9040  1515875   70.96%
#     176    60      105.7171 71394      161.4977       46.9040  1461333   70.96%
#     183    57       86.8349 105130      161.4977       46.9040  1576793   70.96%
#     186    63      109.0993 69134      161.4977       46.9040  1465609   70.96%
#     193    63       98.7421 84391      161.4977       46.9040  1528574   70.96%
#     200    91      113.0574 45732      161.4977       46.9040  1804133   70.96%
# Elapsed time = 8967.63 sec. (7078167.10 ticks, tree = 12.25 MB, solutions = 1)
#     209   108      114.0119 46334      161.4977       46.9040  1956279   70.96%
#     213    94      117.0916 34190      161.4977       46.9040  1810488   70.96%
#     221   115       78.7900 110790      161.4977       46.9040  2141427   70.96%
#     225   113      119.0232 32246      161.4977       46.9040  1962751   70.96%
#     234    99      122.8457 17352      161.4977       46.9040  1815062   70.96%
#     242   103      125.7266  5231      161.4977       46.9040  1816558   70.96%
#     261    72      104.1520 59224      161.4977       46.9040  1553270   70.96%
#     276   115      127.2558  5098      161.4977       46.9040  1816577   70.96%
#     289   125      129.1251  3883      161.4977       46.9040  1967883   70.96%
#     304   126      128.0470  5013      161.4977       46.9040  1816597   70.96%
# Elapsed time = 9023.22 sec. (7088429.93 ticks, tree = 23.59 MB, solutions = 1)
#     329   135      130.7431  3772      161.4977       46.9040  1967906   70.96%
#     354   140      128.1086  4899      161.4977       46.9040  1816616   70.96%
#     367   134       84.0812 110024      161.4977       46.9040  2317053   70.96%
#     381   142      128.1883  4878      161.4977       46.9040  1816623   70.96%
#     408   142      134.8194  3606      161.4977       46.9040  1967973   70.96%
#     433   135       84.7398 109066      161.4977       46.9040  2329945   70.96%
#     450   146    infeasible            161.4977       46.9040  1968005   70.96%
#     479   167      129.2148  4676      161.4977       46.9040  1816673   70.96%
#     497    98      122.7831  5881      161.4977       46.9040  1574089   70.96%
#     581    44       76.8999 111658      161.4977       46.9040  1468555   70.96%
# Elapsed time = 9074.55 sec. (7101104.19 ticks, tree = 2.77 MB, solutions = 1)
#     690   221      135.9861  3068      161.4977       46.9040  1968102   70.96%
#     787   235      139.8030  2890      161.4977       46.9040  1968164   70.96%
#     894   412      129.4389  4048      161.4977       46.9040  2520323   70.96%
#     985   235      145.7615  2440      161.4977       46.9040  1968407   70.96%
#    1086   446      131.7187  3648      161.4977       46.9040  2520452   70.96%
#    1196   525      149.1639  2022      161.4977       46.9040  2938008   70.96%
#    1297   456      138.0311  3249      161.4977       46.9040  2520760   70.96%
#    1409   378      129.3114  3817      161.4977       46.9040  2453643   70.96%
#    1528   480      141.7266  2853      161.4977       46.9040  2520974   70.96%
#    1679   407      135.6667  3375      161.4977       46.9040  2453838   70.96%
# Elapsed time = 9245.21 sec. (7139545.57 ticks, tree = 107.93 MB, solutions = 1)
#    1801   607      136.3965  4111      161.4977       46.9040  3079468   70.96%
#    1899   390      102.8949 84349      161.4977       46.9040  2812615   70.96%
#    1992   767      147.4143  2704      161.4977       46.9040  3165353   70.96%
#    2057   673      136.7325  3727      161.4977       46.9040  3079544   70.96%
#    2126   805      148.0472  2176      161.4977       46.9040  3165546   70.96%
#    2192   813      151.9468  1845      161.4977       46.9040  3165693   70.96%
#    2263   813      156.7058  1516      161.4977       46.9040  3165879   70.96%
#    2332  1157      145.5878  3087      161.4977       46.9040  3483448   70.96%
#    2355   928       84.0572 103162      161.4977       46.9040  3345538   70.96%
#    2364  1155       94.1399 82655      161.4977       46.9040  3643750   70.96%
# Elapsed time = 9392.16 sec. (7179417.36 ticks, tree = 315.08 MB, solutions = 1)
#    2374  1158       96.9526 81999      161.4977       46.9040  3655295   70.96%
#    2384  1168      109.7312 68592      161.4977       46.9040  3755395   70.96%
#    2394  1165      107.3880 64381      161.4977       46.9040  3677089   70.96%
#    2415  1247      119.7942 48992      161.4977       46.9040  3974472   70.96%
#    2437  1312      115.2473 45708      161.4977       46.9040  4175316   70.96%
#    2471  1268    infeasible            161.4977       46.9040  4034316   70.96%
#    2529  1280      127.0019  7984      161.4977       46.9040  4036392   70.96%
#    2634  1290      135.9268  4490      161.4977       46.9040  4036602   70.96%
#    2740  1359      135.0283  3817      161.4977       46.9040  4187233   70.96%
#    2849  1378      135.0283  3696      161.4977       46.9040  4187259   70.96%
# Elapsed time = 9533.82 sec. (7219543.42 ticks, tree = 381.89 MB, solutions = 1)
#    2951  1519      136.4081  3569      161.4977       46.9040  4508705   70.96%
#    3073  1537      137.6681  3481      161.4977       46.9040  4508747   70.96%
#    3199  1469      142.5323  3231      161.4977       46.9040  4349804   70.96%
#    3335  1540    infeasible            161.4977       46.9040  4436390   70.96%
#    3474  1604      141.6698  3530      161.4977       46.9040  4576451   70.96%
#    3591  1719      149.1370  2700      161.4977       46.9040  4648771   70.96%
#    3659  1848      146.8232  2962      161.4977       46.9040  4791953   70.96%
#    3741  1721      151.4109  2284      161.4977       46.9040  4648946   70.96%
#    3794  1866      147.7525  2522      161.4977       46.9040  4792122   70.96%
#    3829  1894      147.7525  2318      161.4977       46.9040  4792190   70.96%
# Elapsed time = 9658.68 sec. (7258458.59 ticks, tree = 544.07 MB, solutions = 1)
#    3836  1539       60.5228 112873      161.4977       46.9040  4702100   70.96%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 47094 rows and 24875 columns.
# MIP Presolve modified 8 coefficients.
# Reduced MIP has 332720 rows, 281752 columns, and 891081 nonzeros.
# Reduced MIP has 155946 binaries, 75945 generals, 0 SOSs, and 43817 indicators.
# Presolve time = 6.80 sec. (4277.32 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 332720 rows, 281752 columns, and 891081 nonzeros.
# Reduced MIP has 155946 binaries, 75945 generals, 0 SOSs, and 43817 indicators.
# Presolve time = 6.00 sec. (12511.21 ticks)
# Represolve time = 24.88 sec. (18915.51 ticks)
#    3837     0       44.9342 122828      161.4977    Cuts: 9990  5148138   70.96%
#    3837     0       45.0598 114484      161.4977    Cuts: 6562  5161870   70.96%
#    3837     0       45.1221 115007      161.4977    Cuts: 9912  5170353   70.96%
#    3837     0       45.1813 113159      161.4977    Cuts: 2881  5181339   70.96%
#    3837     0       45.2383 113403      161.4977    Cuts: 1972  5190864   70.96%
#    3837     0       45.3631 112605      161.4977    Cuts: 1296  5204163   70.96%
#    3837     0       45.4347 112337      161.4977    Cuts: 2499  5214771   70.96%
#    3837     0       45.5162 112687      161.4977    Cuts: 1471  5228167   70.96%
#    3837     2       45.5162 111659      161.4977       46.9040  5228167   70.96%
#    3838     3       46.4589 111753      161.4977       46.9040  5250875   70.96%
#    3839     3       49.7870 111998      161.4977       46.9040  5271165   70.96%
#    3840     4       46.9683 111306      161.4977       46.9040  5274452   70.96%
#    3841     5       55.4433 112571      161.4977       46.9040  5323311   70.96%
#    3842     6       50.1808 109724      161.4977       46.9040  5339553   70.96%
#    3843     7       55.9662 111987      161.4977       46.9040  5364849   70.96%
#    3844     8       50.9863 109652      161.4977       46.9040  5378901   70.96%
#    3846     6       49.1624 111450      161.4977       46.9040  5349379   70.96%
# Elapsed time = 12680.59 sec. (9927227.10 ticks, tree = 0.02 MB, solutions = 1)
#    3848     8       58.3046 110005      161.4977       46.9040  5405003   70.96%
#    3850     9       58.9056 110287      161.4977       46.9040  5416989   70.96%
#    3851     4       46.7781 111774      161.4977       46.9040  5266729   70.96%
#    3854    13       56.0581 111687      161.4977       46.9040  5496844   70.96%
#    3855    14       61.1855 109550      161.4977       46.9040  5541489   70.96%
#    3858    13       52.6756 112160      161.4977       46.9040  5465223   70.96%
#    3860    15       66.5245 109581      161.4977       46.9040  5549312   70.96%
#    3863    16       66.3889 112098      161.4977       46.9040  5573046   70.96%
#    3865    14       50.6253 111857      161.4977       46.9040  5473252   70.96%
#    3866    19       52.2790 109650      161.4977       46.9040  5633643   70.96%
# Elapsed time = 12913.46 sec. (9994894.88 ticks, tree = 0.58 MB, solutions = 1)
#    3871    18       50.6236 110066      161.4977       46.9040  5630484   70.96%
#    3872    20       52.6407 109666      161.4977       46.9040  5638909   70.96%
#    3877    28       58.7966 111651      161.4977       46.9040  5789296   70.96%
#    3886    27       67.2128 108919      161.4977       46.9040  5746371   70.96%
#    3896    38       67.8094 110304      161.4977       46.9040  5896777   70.96%
#    3903    26       52.0212 111689      161.4977       46.9040  5724664   70.96%
#    3909    42       70.9041 108393      161.4977       46.9040  5921960   70.96%
#    3912    43       71.2182 108260      161.4977       46.9040  5930854   70.96%
#    3916    35       68.2111 107926      161.4977       46.9040  5875413   70.96%
#    3924    36       70.2314 107131      161.4977       46.9040  5887375   70.96%
# Elapsed time = 13672.23 sec. (10048293.17 ticks, tree = 2.16 MB, solutions = 1)
#    3927    37       61.1295 110491      161.4977       46.9040  5936275   70.96%
#    3928    38       59.1640 111007      161.4977       46.9040  5969359   70.96%
#    3929    77       76.5011 105518      161.4977       46.9040  6305930   70.96%
#    3933    63       72.8898 107633      161.4977       46.9040  6218150   70.96%
#    3935    53       59.1257 110778      161.4977       46.9040  6150794   70.96%
#    3936    91       67.4679 105436      161.4977       46.9040  6480102   70.96%
#    3939   104       60.8670 110636      161.4977       46.9040  6769758   70.96%
#    3943   105       76.9573 104895      161.4977       46.9040  6796937   70.96%
#    3952   111       78.4903 102504      161.4977       46.9040  6814055   70.96%
#    3962   109       76.3907 103024      161.4977       46.9040  6836848   70.96%
# Elapsed time = 14595.43 sec. (10194576.61 ticks, tree = 7.32 MB, solutions = 1)
#    3972   118       79.3268 102476      161.4977       46.9040  6843602   70.96%
#    3986   117       73.3735 99971      161.4977       46.9040  6839843   70.96%
#    3996   110       76.6202 102315      161.4977       46.9040  6839157   70.96%
#    4005   124       93.9323 87846      161.4977       46.9040  6882035   70.96%
#    4021   130       94.8259 82874      161.4977       46.9040  6893521   70.96%
#    4039   138      105.5703 67795      161.4977       46.9040  6904201   70.96%
#    4089   125       66.7600 107732      161.4977       46.9040  6933494   70.96%
#    4102   145      108.0832 63774      161.4977       46.9040  6916808   70.96%
#    4120   128       85.2380 94938      161.4977       46.9040  6908058   70.96%
#    4142   115       63.0566 104247      161.4977       46.9040  6978384   70.96%
# Elapsed time = 14862.88 sec. (10235088.33 ticks, tree = 8.10 MB, solutions = 1)
#    4175   141       85.0857 94864      161.4977       46.9040  7104085   70.96%
#    4203   111       59.5611 106574      161.4977       46.9040  7009209   70.96%
#    4249   215      131.9510  7971      161.4977       46.9040  7271447   70.96%
#    4301   226      135.7810  7680      161.4977       46.9040  7271542   70.96%
#    4366   150       92.4440 80660      161.4977       46.9040  7143965   70.96%
#    4428   235      137.3233  7150      161.4977       46.9040  7271681   70.96%
#    4502   152       83.7941 89191      161.4977       46.9040  7171464   70.96%
#    4578   225       91.2715 84070      161.4977       46.9040  7402598   70.96%
#    4655   155       94.3308 76661      161.4977       46.9040  7155057   70.96%
#    4744   149       69.0030 104394      161.4977       46.9040  7170316   70.96%
# Elapsed time = 14985.07 sec. (10273636.37 ticks, tree = 12.98 MB, solutions = 1)
#    4828   253       72.3085 98021      161.4977       46.9040  7512396   70.96%
#    4906   277      149.3703  5441      161.4977       46.9040  7272216   70.96%
#    4967   260       81.5622 93824      161.4977       46.9040  7535980   70.96%
#    5058   443      151.9171  4894      161.4977       46.9040  7928191   70.96%
#    5131   461      153.9156  4510      161.4977       46.9040  7928331   70.96%
#    5250   474      154.8172  4301      161.4977       46.9040  7928394   70.96%
#    5338   497      155.8736  4012      161.4977       46.9040  7928657   70.96%
#    5477   309      112.1743 59979      161.4977       46.9040  7719847   70.96%
#    5595   517      160.4003  3565      161.4977       46.9040  7928838   70.96%
#    5733   333      123.0916 29342      161.4977       46.9040  7779656   70.96%
# Elapsed time = 15174.42 sec. (10312373.90 ticks, tree = 44.29 MB, solutions = 1)
#    5843   461       78.9102 96569      161.4977       46.9040  8040411   70.96%
#    5965   545      143.5980  3165      161.4977       46.9040  8169634   70.96%
#    6094   579    infeasible            161.4977       46.9040  8318892   70.96%
#    6244   557      152.7473  2730      161.4977       46.9040  8169822   70.96%
#    6385   573      156.7187  2524      161.4977       46.9040  8169918   70.96%
#    6528   574      158.2217  2332      161.4977       46.9040  8170003   70.96%
#    6667   670      141.3670  1987      161.4977       46.9040  8366609   70.96%
#    6789   684      143.6603  1817      161.4977       46.9040  8366689   70.96%
#    6933   866      156.7887  2366      161.4977       46.9040  8504920   70.96%
#    7075   700      147.9042  1389      161.4977       46.9040  8366890   70.96%
# Elapsed time = 15322.78 sec. (10350880.12 ticks, tree = 122.19 MB, solutions = 1)
#    7214   703      150.1220  1206      161.4977       46.9040  8366974   70.96%
#    7315   726      151.1516  1030      161.4977       46.9040  8367038   70.96%
#    7446  1113      146.2337  3367      161.4977       46.9040  8976391   70.96%
#    7569  1124      147.7613  3126      161.4977       46.9040  8976482   70.96%
#    7694  1146      150.5259  2975      161.4977       46.9040  8976555   70.96%
#    7855  1251      158.4215   316      161.4977       46.9040  9008419   70.96%
#    8011  1262      158.7512   171      161.4977       46.9040  9008468   70.96%
# *  8177  1260      integral     0      159.2379       46.9040  9008547   70.54%
#    8181  1357      106.5943 47379      159.2379       46.9040  9361774   70.54%
#    8273  1359      144.4038  2509      159.2379       46.9040  9239788   70.54%
#    8370  1555        cutoff            159.2379       46.9040  9577333   70.54%
# Elapsed time = 15460.26 sec. (10389403.65 ticks, tree = 334.93 MB, solutions = 2)
#    8378  1452       59.8196 105766      159.2379       46.9040  9444061   70.54%
#    8381  1453       64.8098 107492      159.2379       46.9040  9456383   70.54%
#    8386  1580        cutoff            159.2379       46.9040  9629411   70.54%
#    8389  1459      118.0912 84053      159.2379       46.9040  9563198   70.54%
#    8390  1591       97.6409 98892      159.2379       46.9040  9702390   70.54%
#    8391  1556       59.0445 109801      159.2379       46.9040  9616108   70.54%
#    8392  1599       55.9045 109437      159.2379       46.9040  9729667   70.54%
#    8394  1608       62.3590 111711      159.2379       46.9040  9934276   70.54%
#    8398  1611       64.8904 111378      159.2379       46.9040  9949741   70.54%

# %% [markdown]
# ## Save Final Schedule

# %%
final_schedule_df.to_csv(join(output_path, "fct_schedules.csv"), sep=',', encoding='utf-8', index=False)

# %%
schedules, gap_dict, stop_factor, bus_lines, stops, schedules_per_line, max_gap_threshold, start_times_dict, max_lines, min_service_requirements = get_opt_parameters(output_path)
